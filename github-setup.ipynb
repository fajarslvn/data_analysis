# %%
from os.path import join
from google.colab import drive

ROOT = "/content/drive"
print(ROOT)

drive.mount(ROOT)   

MY_GOOGLE_DRIVE_PATH = "My Drive/ai/machine_learning"
GIT_USERNAME = "fajarslvn" 
GIT_TOKEN = "05bdeae8a1191f634cefa416235c5603656eb79a"  
GIT_REPOSITORY = "machine_learning" 

PROJECT_PATH = join(ROOT, MY_GOOGLE_DRIVE_PATH)

print("PROJECT_PATH: ", PROJECT_PATH)   

# !mkdir "{PROJECT_PATH}"    

GIT_PATH = "https://" + GIT_TOKEN + "@github.com/" + GIT_USERNAME + "/" + GIT_REPOSITORY + ".git"
print("GIT_PATH: ", GIT_PATH)
# Out:
# /content/drive
# Mounted at /content/drive
# PROJECT_PATH:  /content/drive/My Drive/ai/machine_learning
# GIT_PATH:  https://05bdeae8a1191f634cefa416235c5603656eb79a@github.com/fajarslvn/machine_learning.git

# %% [markdown]
# ## Clone repository

# %%
# %cd "{PROJECT_PATH}"
# !git clone "{GIT_PATH}"
# Out:
# /content/drive/My Drive/ai
# fatal: destination path 'machine_learning' already exists and is not an empty directory.

# %% [markdown]
# ## Add new files to github and check status

# %%
# %cd /content/drive/My Drive/ai/machine_learning
# !git add .
# !git status
# Out:
# /content/drive/My Drive/ai/machine_learning

# %% [markdown]
# ## Git Commit

# %%
# !git commit -m "new"
# !git config --global user.email "jarphish@gmail.com"
# !git config --global user.name "fajarslvn"
# Out:
# [main 857ccff] new
#  24 files changed, 20041 insertions(+), 108 deletions(-)
#  create mode 100644 ds-survey-analysis/ds_survey_2020_responses.csv
#  rename {sales gadget => electronicshop-sales-analysis}/README.md (100%)
#  rename {sales gadget => electronicshop-sales-analysis}/Sales Analysis.ipynb (100%)
#  rename {sales gadget => electronicshop-sales-analysis}/Sales_Data/Sales_April_2019.csv (100%)
#  rename {sales gadget => electronicshop-sales-analysis}/Sales_Data/Sales_August_2019.csv (100%)
#  rename {sales gadget => electronicshop-sales-analysis}/Sales_Data/Sales_December_2019.csv (100%)
#  rename {sales gadget => electronicshop-sales-analysis}/Sales_Data/Sales_February_2019.csv (100%)
#  rename {sales gadget => electronicshop-sales-analysis}/Sales_Data/Sales_January_2019.csv (100%)
#  rename {sales gadget => electronicshop-sales-analysis}/Sales_Data/Sales_July_2019.csv (100%)
#  rename {sales gadget => electronicshop-sales-analysis}/Sales_Data/Sales_June_2019.csv (100%)
#  rename {sales gadget => electronicshop-sales-analysis}/Sales_Data/Sales_March_2019.csv (100%)
#  rename {sales gadget => electronicshop-sales-analysis}/Sales_Data/Sales_May_2019.csv (100%)
#  rename {sales gadget => electronicshop-sales-analysis}/Sales_Data/Sales_November_2019.csv (100%)
#  rename {sales gadget => electronicshop-sales-analysis}/Sales_Data/Sales_October_2019.csv (100%)
#  rename {sales gadget => electronicshop-sales-analysis}/Sales_Data/Sales_September_2019.csv (100%)
#  rename {sales gadget => electronicshop-sales-analysis}/all_data.csv (100%)
#  rename {sales gadget => electronicshop-sales-analysis}/electronic-shop.html (100%)
#  delete mode 100644 graph/bokeh.ipynb
#  delete mode 100644 graph/bokeh_dashboard.py
#  delete mode 100644 graph/graph.html
#  create mode 100644 superstore-sales-analysis/superstore.ipynb
#  create mode 100644 superstore-sales-analysis/superstore_sales.xlsx

# %% [markdown]
# ## Push to repository

# %%
# !git push
# Out:
# Counting objects: 9, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (9/9), done.
# Writing objects: 100% (9/9), 8.43 MiB | 4.77 MiB/s, done.
# Total 9 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/fajarslvn/machine_learning.git
#    1384e25..857ccff  main -> main
