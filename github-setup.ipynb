# %%
from os.path import join
from google.colab import drive

ROOT = "/content/drive"
print(ROOT)

drive.mount(ROOT)   

MY_GOOGLE_DRIVE_PATH = "My Drive/ai/machine_learning"
GIT_USERNAME = "fajarslvn" 
GIT_TOKEN = "05bdeae8a1191f634cefa416235c5603656eb79a"  
GIT_REPOSITORY = "machine_learning" 

PROJECT_PATH = join(ROOT, MY_GOOGLE_DRIVE_PATH)

print("PROJECT_PATH: ", PROJECT_PATH)   

# !mkdir "{PROJECT_PATH}"    

GIT_PATH = "https://" + GIT_TOKEN + "@github.com/" + GIT_USERNAME + "/" + GIT_REPOSITORY + ".git"
print("GIT_PATH: ", GIT_PATH)
# Out:
# /content/drive
# Mounted at /content/drive
# PROJECT_PATH:  /content/drive/My Drive/ai/machine_learning
# GIT_PATH:  https://05bdeae8a1191f634cefa416235c5603656eb79a@github.com/fajarslvn/machine_learning.git

# %% [markdown]
# ## Clone repository

# %%
# %cd "{PROJECT_PATH}"
# !git clone "{GIT_PATH}"
# Out:
# /content/drive/My Drive/ai
# fatal: destination path 'machine_learning' already exists and is not an empty directory.

# %% [markdown]
# ## Add new files to github and check status

# %%
# %cd /content/drive/My Drive/ai/machine_learning
# !git add .
# !git status
# Out:
# /content/drive/My Drive/ai/machine_learning
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Changes to be committed:
#   (use "git reset HEAD <file>..." to unstage)
#
# 	renamed:    scikit-learn/tuts01.py -> ML from scratch/tuts01.py
# 	modified:   github-setup.ipynb

# %% [markdown]
# ## Git Commit

# %%
# !git commit -m "renamed"
# !git config --global user.email "jarphish@gmail.com"
# !git config --global user.name "fajarslvn"
# Out:
# [main 2ca8386] add
#  3 files changed, 88 insertions(+), 88 deletions(-)
#  rewrite github-setup.ipynb (92%)
#  rewrite sales gadget/electronic-shop.html (89%)

# %% [markdown]
# ## Push to repository

# %%
# !git push
# Out:
# Counting objects: 6, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (6/6), done.
# Writing objects: 100% (6/6), 6.91 KiB | 1010.00 KiB/s, done.
# Total 6 (delta 5), reused 0 (delta 0)
# remote: Resolving deltas: 100% (5/5), completed with 5 local objects.
# To https://github.com/fajarslvn/machine_learning.git
#    8d1ff22..2ca8386  main -> main
