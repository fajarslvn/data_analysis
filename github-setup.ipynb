# %%
from os.path import join
from google.colab import drive

ROOT = "/content/drive"
print(ROOT)

drive.mount(ROOT)   

MY_GOOGLE_DRIVE_PATH = "My Drive/ai/machine_learning"
GIT_USERNAME = "fajarslvn" 
GIT_TOKEN = "05bdeae8a1191f634cefa416235c5603656eb79a"  
GIT_REPOSITORY = "machine_learning" 

PROJECT_PATH = join(ROOT, MY_GOOGLE_DRIVE_PATH)

print("PROJECT_PATH: ", PROJECT_PATH)   

# !mkdir "{PROJECT_PATH}"    

GIT_PATH = "https://" + GIT_TOKEN + "@github.com/" + GIT_USERNAME + "/" + GIT_REPOSITORY + ".git"
print("GIT_PATH: ", GIT_PATH)
# Out:
# /content/drive
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# PROJECT_PATH:  /content/drive/My Drive/ai/machine_learning
# GIT_PATH:  https://05bdeae8a1191f634cefa416235c5603656eb79a@github.com/fajarslvn/machine_learning.git

# %% [markdown]
# ## Clone repository

# %%
# %cd "{PROJECT_PATH}"
# !git clone "{GIT_PATH}"
# Out:
# /content/drive/My Drive/ai
# Cloning into 'machine_learning'...
# remote: Enumerating objects: 125, done.
# remote: Counting objects: 100% (125/125), done.
# remote: Compressing objects: 100% (70/70), done.
# remote: Total 125 (delta 58), reused 95 (delta 41), pack-reused 0
# Receiving objects: 100% (125/125), 3.20 MiB | 9.15 MiB/s, done.
# Resolving deltas: 100% (58/58), done.

# %% [markdown]
# ## Add new files to github and check status

# %%
# %cd "{PROJECT_PATH}"
# !git add .
# !git status
# Out:
# /content/drive/My Drive/ai/machine_learning
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Changes to be committed:
#   (use "git reset HEAD <file>..." to unstage)
#
# 	new file:   codeserver.ipynb
# 	new file:   github-setup.ipynb
# 	new file:   graph/bokeh_dashboard.py
# 	new file:   graph/graph.html

# %% [markdown]
# ## Git Commit

# %%
# !git commit -m "Fix dfl and cities variable values"
# !git config --global user.email "jarphish@gmail.com"
# !git config --global user.name "fajarslvn"
# Out:
# [main 3d99466] Fix dfl and cities variable values
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite sales gadget/Sales Analysis.ipynb (81%)

# %% [markdown]
# ## Push to repository

# %%
# !git push
# Out:
# Counting objects: 4, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 13.55 KiB | 1.69 MiB/s, done.
# Total 4 (delta 3), reused 0 (delta 0)
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To https://github.com/fajarslvn/data_analysis.git
#    ba81133..3d99466  main -> main
