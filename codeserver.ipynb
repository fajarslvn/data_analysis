# %%
# !pip install colabcode
# Out:
# Collecting colabcode
#   Downloading https://files.pythonhosted.org/packages/9d/4c/7981fe8975255e14fd653ddcb9670671602a3871d21f615dfe79b733837a/colabcode-0.1.1-py3-none-any.whl
# Collecting pyngrok>=5.0.0
#   Downloading https://files.pythonhosted.org/packages/e2/19/af0fc6c11cc13f8a31e9dbec21af745337be8a40b5738cd30f08a483eac3/pyngrok-5.0.1.tar.gz
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.6/dist-packages (from pyngrok>=5.0.0->colabcode) (3.13)
# Building wheels for collected packages: pyngrok
#   Building wheel for pyngrok (setup.py) ... done
#   Created wheel for pyngrok: filename=pyngrok-5.0.1-cp36-none-any.whl size=18822 sha256=4fe7ce8100b174f820f631dc596bf05db001ba0394fee2a75795154827dcf0d6
#   Stored in directory: /root/.cache/pip/wheels/94/01/05/d39efb8f6b40a411354b4168ca9dda99e6f8d586e458e97551
# Successfully built pyngrok
# Installing collected packages: pyngrok, colabcode
# Successfully installed colabcode-0.1.1 pyngrok-5.0.1

# %%
from colabcode import ColabCode
ColabCode(port=7000, password='khalid', mount_drive=True)
# Out:
# Code Server can be accessed on: NgrokTunnel: "http://6669205e1517.ngrok.io" -> "http://localhost:7000"
# Mounted at /content/drive
# [2021-01-03T13:50:59.050Z] info  code-server 3.7.4 11f53784c58f68e7f4c5b3b8dae9407caa41725b
# [2021-01-03T13:50:59.051Z] info  Using user-data-dir ~/.local/share/code-server
# [2021-01-03T13:50:59.062Z] info  Using config file ~/.config/code-server/config.yaml
# [2021-01-03T13:50:59.062Z] info  HTTP server listening on http://127.0.0.1:7000
# [2021-01-03T13:50:59.063Z] info    - Authentication is enabled
# [2021-01-03T13:50:59.063Z] info      - Using password from $PASSWORD
# [2021-01-03T13:50:59.063Z] info    - Not serving HTTPS
