# %%
# !pip install colabcode
# Out:
# Collecting colabcode
#   Downloading https://files.pythonhosted.org/packages/9d/4c/7981fe8975255e14fd653ddcb9670671602a3871d21f615dfe79b733837a/colabcode-0.1.1-py3-none-any.whl
# Collecting pyngrok>=5.0.0
#   Downloading https://files.pythonhosted.org/packages/ea/63/e086f165125e9bf2e71c0db2955911baaaa0af8947ab5c7b3771bdf4d4d5/pyngrok-5.0.0.tar.gz
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.6/dist-packages (from pyngrok>=5.0.0->colabcode) (3.13)
# Building wheels for collected packages: pyngrok
#   Building wheel for pyngrok (setup.py) ... done
#   Created wheel for pyngrok: filename=pyngrok-5.0.0-cp36-none-any.whl size=18781 sha256=6a28a43d074d0a3262a91d4f4fa3e5021858ef6c2c8dc63a6effb73c902f65c0
#   Stored in directory: /root/.cache/pip/wheels/95/df/23/af8dde08c3fcdc7b966adcacef48ab29aa3b0b1860df5d2b79
# Successfully built pyngrok
# Installing collected packages: pyngrok, colabcode
# Successfully installed colabcode-0.1.1 pyngrok-5.0.0

# %%
from colabcode import ColabCode
ColabCode(port=7000, password='khalid', mount_drive=True)
# Out:
# Code Server can be accessed on: NgrokTunnel: "http://f3678ffef0ec.ngrok.io" -> "http://localhost:7000"
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [2020-12-28T09:31:44.197Z] info  code-server 3.7.4 11f53784c58f68e7f4c5b3b8dae9407caa41725b
# [2020-12-28T09:31:44.199Z] info  Using user-data-dir ~/.local/share/code-server
# [2020-12-28T09:31:44.214Z] info  Using config file ~/.config/code-server/config.yaml
# [2020-12-28T09:31:44.215Z] info  HTTP server listening on http://127.0.0.1:7000
# [2020-12-28T09:31:44.215Z] info    - Authentication is enabled
# [2020-12-28T09:31:44.215Z] info      - Using password from $PASSWORD
# [2020-12-28T09:31:44.215Z] info    - Not serving HTTPS
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-afd918c5e9da> in <module>()
#       1 from colabcode import ColabCode
# ----> 2 ColabCode(port=7000, password='khalid', mount_drive=True)
#
# /usr/local/lib/python3.6/dist-packages/colabcode/code.py in __init__(self, port, password, authtoken, mount_drive)
#      24         self._install_extensions()
#      25         self._start_server()
# ---> 26         self._run_code()
#      27
#      28     def _install_code(self):
#
# /usr/local/lib/python3.6/dist-packages/colabcode/code.py in _run_code(self)
#      64             universal_newlines=True,
#      65         ) as proc:
# ---> 66             for line in proc.stdout:
#      67                 print(line, end="")
#
# KeyboardInterrupt:
