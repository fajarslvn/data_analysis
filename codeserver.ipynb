# %%
# !pip install colabcode
# Out:
# Requirement already satisfied: colabcode in /usr/local/lib/python3.6/dist-packages (0.1.1)
# Requirement already satisfied: pyngrok>=5.0.0 in /usr/local/lib/python3.6/dist-packages (from colabcode) (5.0.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.6/dist-packages (from pyngrok>=5.0.0->colabcode) (3.13)

# %%
from colabcode import ColabCode
ColabCode(port=7000, password='khalid', mount_drive=True)
# Out:
# Code Server can be accessed on: NgrokTunnel: "http://499a89887025.ngrok.io" -> "http://localhost:7000"
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [2020-12-28T10:17:10.559Z] info  code-server 3.7.4 11f53784c58f68e7f4c5b3b8dae9407caa41725b
# [2020-12-28T10:17:10.560Z] info  Using user-data-dir ~/.local/share/code-server
# [2020-12-28T10:17:10.571Z] info  Using config file ~/.config/code-server/config.yaml
# [2020-12-28T10:17:10.571Z] info  HTTP server listening on http://127.0.0.1:7000
# [2020-12-28T10:17:10.571Z] info    - Authentication is enabled
# [2020-12-28T10:17:10.571Z] info      - Using password from $PASSWORD
# [2020-12-28T10:17:10.571Z] info    - Not serving HTTPS
