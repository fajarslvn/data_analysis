# %%
# !pip install colabcode
# Out:
# ...
#   Created wheel for pyngrok: filename=pyngrok-5.0.1-cp36-none-any.whl size=18822 sha256=9845261a7512bf9c6fedb754bfd2cb9b5a7d1e27691eaa108b246b930cac90f9
#   Stored in directory: /root/.cache/pip/wheels/94/01/05/d39efb8f6b40a411354b4168ca9dda99e6f8d586e458e97551
# Successfully built pyngrok
# ...

# %%
from colabcode import ColabCode
ColabCode(port=7000, password='khalid', mount_drive=True)
# Out:
# Code Server can be accessed on: NgrokTunnel: "http://ab366212f06b.ngrok.io" -> "http://localhost:7000"
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [2020-12-31T03:12:05.341Z] info  code-server 3.7.4 11f53784c58f68e7f4c5b3b8dae9407caa41725b
# [2020-12-31T03:12:05.343Z] info  Using user-data-dir ~/.local/share/code-server
# [2020-12-31T03:12:05.359Z] info  Using config file ~/.config/code-server/config.yaml
# [2020-12-31T03:12:05.359Z] info  HTTP server listening on http://127.0.0.1:7000
# [2020-12-31T03:12:05.359Z] info    - Authentication is enabled
# [2020-12-31T03:12:05.359Z] info      - Using password from $PASSWORD
# [2020-12-31T03:12:05.359Z] info    - Not serving HTTPS
