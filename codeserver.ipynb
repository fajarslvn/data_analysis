# %%
'''
# Stop colab from disconnecting (paste it in console devtool) 
function KeepWorking(){
 console.log("Working");
 document.querySelector("colab-connect-button").click()   
}setInterval(KeepWorking,60000)

# Install tools
wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip -O ngrok-stable-linux-amd64.zip
unzip -u ngrok-stable-linux-amd64.zip
chmod +x ngrok
cd to folder project
install virtual environment -> apt-get install python3-venv
build new virtual environment -> python -m venv venv
activate virtual environment -> source venv/bin/activate
pip install plotly==4.14.3
pip install pip install dash==1.18.1
pip install dash-bootstrap-components
venv -> deactivate
'''

# %%
# !pip install colabcode
# Out:
# ...
#   Created wheel for pyngrok: filename=pyngrok-5.0.1-cp36-none-any.whl size=18822 sha256=57b13e67cea8b662fd6876607734ba71443694d62b236b5d0cca6a458ec1f257
#   Stored in directory: /root/.cache/pip/wheels/94/01/05/d39efb8f6b40a411354b4168ca9dda99e6f8d586e458e97551
# Successfully built pyngrok
# ...

# %%
from colabcode import ColabCode
ColabCode(port=7200, password='khalid', mount_drive=True)
# Out:
# Code Server can be accessed on: NgrokTunnel: "http://2b5d3d7df775.ngrok.io" -> "http://localhost:7200"
# Mounted at /content/drive
# [2021-01-18T03:25:19.455Z] info  code-server 3.7.4 11f53784c58f68e7f4c5b3b8dae9407caa41725b
# [2021-01-18T03:25:19.456Z] info  Using user-data-dir ~/.local/share/code-server
# [2021-01-18T03:25:19.467Z] info  Using config file ~/.config/code-server/config.yaml
# [2021-01-18T03:25:19.467Z] info  HTTP server listening on http://127.0.0.1:7200
# [2021-01-18T03:25:19.467Z] info    - Authentication is enabled
# [2021-01-18T03:25:19.467Z] info      - Using password from $PASSWORD
# [2021-01-18T03:25:19.467Z] info    - Not serving HTTPS
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-687b397368f8> in <module>()
#       1 from colabcode import ColabCode
# ----> 2 ColabCode(port=7200, password='khalid', mount_drive=True)
#
# ...
