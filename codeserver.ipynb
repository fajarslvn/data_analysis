# %%
'''
# Stop colab from disconnecting (paste it in console devtool) 
function KeepWorking(){
 console.log("Working");
 document.querySelector("colab-connect-button").click()   
}setInterval(KeepWorking,60000)

# Install tools
wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip -O ngrok-stable-linux-amd64.zip
unzip -u ngrok-stable-linux-amd64.zip
chmod +x ngrok
cd to folder project
install virtual environment ->apt-get install python3-venv
build new virtual environment -> python -m venv venv
activate virtual environment -> source venv/bin/activate
pip install plotly==4.14.1
pip install pip install dash==1.18.1
pip install dash-bootstrap-components
venv -> deactivate
'''

# %%
# !pip install colabcode
# Out:
# Requirement already satisfied: colabcode in /usr/local/lib/python3.6/dist-packages (0.1.1)
# Requirement already satisfied: pyngrok>=5.0.0 in /usr/local/lib/python3.6/dist-packages (from colabcode) (5.0.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.6/dist-packages (from pyngrok>=5.0.0->colabcode) (3.13)

# %%
from colabcode import ColabCode
ColabCode(port=7200, password='khalid', mount_drive=True)
# Out:
# Code Server can be accessed on: NgrokTunnel: "http://b68224dfe9bc.ngrok.io" -> "http://localhost:7200"
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [2021-01-17T07:08:44.415Z] info  code-server 3.7.4 11f53784c58f68e7f4c5b3b8dae9407caa41725b
# [2021-01-17T07:08:44.416Z] info  Using user-data-dir ~/.local/share/code-server
# [2021-01-17T07:08:44.427Z] info  Using config file ~/.config/code-server/config.yaml
# [2021-01-17T07:08:44.427Z] info  HTTP server listening on http://127.0.0.1:7200
# [2021-01-17T07:08:44.427Z] info    - Authentication is enabled
# [2021-01-17T07:08:44.427Z] info      - Using password from $PASSWORD
# [2021-01-17T07:08:44.427Z] info    - Not serving HTTPS
